# %%
import cv2 as cv 
from PIL import Image 
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = Image.open('foto.jpg') 
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=671x572>

# %%
img_arr = np.array(img)

# %%
img_arr.shape
# Out:
# (572, 671, 3)

# %%
plt.imshow(img_arr)
plt.title('RGB image')
plt.axis('off')
plt.show()

# %%
red_channel = img_arr[:, :, 0]
green_channel = img_arr[:, :, 1]
blue_channel = img_arr[:, :, 2]

# %%
img_arr[0].shape
# Out:
# (671, 3)

# %%
red_channel.shape
# Out:
# (572, 671)

# %%
zeros = np.zeros_like(blue_channel)

# %%
# img_arr

# %%
# Convert BGR to RGB
img_rgb = cv.cvtColor(img_arr, cv.COLOR_BGR2RGB)
